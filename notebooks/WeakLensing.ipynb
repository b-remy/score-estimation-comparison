# %%
# %pylab inline
import tensorflow_datasets as tfds
from nsec.datasets.massivenu import MassiveNu
import tensorflow as tf
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataset = tfds.load(name="massive_nu", split="train")

# %%
def preprocessing_fn(im):
    im = tf.image.resize_with_crop_or_pad(tf.expand_dims(im['map'],-1), 320, 320)
    return im

# %%
dataset = dataset.map(preprocessing_fn)

# %%
for kappa_map in dataset.take(1):  # Only take a single example
  imshow(kappa_map)
